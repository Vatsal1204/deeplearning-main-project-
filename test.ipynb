# %%
# test_installation.py
print("🔍 Testing library imports...\n")

libraries_to_test = {
    "pandas": "pd",
    "numpy": "np",
    "requests": "requests",
    "bs4": "BeautifulSoup",
    "transformers": "pipeline",
    "torch": "torch",
    "gradio": "gr",
    "whois": "whois",
}

for lib, alias in libraries_to_test.items():
    try:
        if lib == "bs4":
            from bs4 import BeautifulSoup
            print(f"✅ {lib} - OK")
        else:
            module = __import__(lib)
            print(f"✅ {lib} - OK")
    except ImportError as e:
        print(f"❌ {lib} - FAILED: {e}")

print("\n✅ Test complete!")
# Out:
# 🔍 Testing library imports...
#
# ❌ pandas - FAILED: No module named 'pandas'
# ✅ numpy - OK
# ✅ requests - OK
# ❌ bs4 - FAILED: No module named 'bs4'
# ❌ transformers - FAILED: No module named 'transformers'
# ❌ torch - FAILED: No module named 'torch'
# ❌ gradio - FAILED: No module named 'gradio'
# ❌ whois - FAILED: No module named 'whois'
#
# ✅ Test complete!

# %%
# test_installation.py
print("🔍 Testing library imports...\n")

libraries_to_test = {
    "pandas": "pd",
    "numpy": "np", 
    "requests": "requests",
    "bs4": "BeautifulSoup",
    "transformers": "pipeline",
    "torch": "torch",
    "gradio": "gr",
    "whois": "whois",
}

for lib, alias in libraries_to_test.items():
    try:
        if lib == "bs4":
            from bs4 import BeautifulSoup
            print(f"✅ {lib} - OK")
        else:
            module = __import__(lib)
            print(f"✅ {lib} - OK")
    except ImportError as e:
        print(f"❌ {lib} - FAILED: {e}")

print("\n✅ Test complete!")
# Out:
# 🔍 Testing library imports...
#
# ❌ pandas - FAILED: No module named 'pandas'
# ✅ numpy - OK
# ✅ requests - OK
# ❌ bs4 - FAILED: No module named 'bs4'
# ❌ transformers - FAILED: No module named 'transformers'
# ❌ torch - FAILED: No module named 'torch'
# ❌ gradio - FAILED: No module named 'gradio'
# ❌ whois - FAILED: No module named 'whois'
#
# ✅ Test complete!
